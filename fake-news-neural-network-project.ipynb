# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import nltk
from 
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data = pd.read_csv("news.csv")

# %%
data
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# 5           6903                                        Tehran, USA
# 6           7341  Girl Horrified At What She Watches Boyfriend D...
# 7             95                  ‘Britain’s Schindler’ Dies at 106
# 8           4869  Fact check: Trump and Clinton at the 'commande...
# 9           2909  Iran reportedly makes new push for uranium con...
# 10          1357  With all three Clintons in Iowa, a glimpse at ...
# 11           988  Donald Trump’s Shockingly Weak Delegate Game S...
# 12          7041  Strong Solar Storm, Tech Risks Today | S0 News...
# ...

# %%
data_L= pd.read_csv('train.csv',header=None)
data_L.columns = ['Index','Label','Statement','Topic','Speaker','designation','Location','Affliation','PF',"F","BT",'HT','MT','Context']

# %%
data_L
# Out:
#             Index        Label  \
# 0       2635.json        FALSE
# 1      10540.json    half-true
# 2        324.json  mostly-true
# 3       1123.json        FALSE
# 4       9028.json    half-true
# 5      12465.json         TRUE
# 6       2342.json  barely-true
# 7        153.json    half-true
# 8       5602.json    half-true
# 9       9741.json  mostly-true
# 10      7115.json  mostly-true
# 11      4148.json    half-true
# 12      5947.json        FALSE
# 13      8616.json  mostly-true
# 14      8705.json  barely-true
# 15     10683.json    half-true
# 16       620.json         TRUE
# 17      3863.json  barely-true
# 18     12372.json    half-true
# 19     12385.json  mostly-true
# 20     10173.json        FALSE
# 21      9867.json  mostly-true
# 22     12408.json  mostly-true
# 23      2673.json    half-true
# 24      7057.json  barely-true
# 25     10215.json        FALSE
# 26     12517.json  mostly-true
# 27      3910.json    half-true
# 28     11092.json        FALSE
# ...

# %%
data_L.dtypes
# Out:
# Index           object
# Label           object
# Statement       object
# Topic           object
# Speaker         object
# designation     object
# Location        object
# Affliation      object
# PF             float64
# F              float64
# BT             float64
# HT             float64
# MT             float64
# Context         object
# dtype: object

# %%
data_L= pd.DataFrame(data_L)

# %%
data_L
# Out:
#             Index        Label  \
# 0       2635.json        FALSE
# 1      10540.json    half-true
# 2        324.json  mostly-true
# 3       1123.json        FALSE
# 4       9028.json    half-true
# 5      12465.json         TRUE
# 6       2342.json  barely-true
# 7        153.json    half-true
# 8       5602.json    half-true
# 9       9741.json  mostly-true
# 10      7115.json  mostly-true
# 11      4148.json    half-true
# 12      5947.json        FALSE
# 13      8616.json  mostly-true
# 14      8705.json  barely-true
# 15     10683.json    half-true
# 16       620.json         TRUE
# 17      3863.json  barely-true
# 18     12372.json    half-true
# 19     12385.json  mostly-true
# 20     10173.json        FALSE
# 21      9867.json  mostly-true
# 22     12408.json  mostly-true
# 23      2673.json    half-true
# 24      7057.json  barely-true
# 25     10215.json        FALSE
# 26     12517.json  mostly-true
# 27      3910.json    half-true
# 28     11092.json        FALSE
# ...

# %%
dt= pd.read_csv('train.tsv',sep='\t')

# %%
y_label_dict = {"pants-fire" : 0, "FALSE" : 1, "barely-true" : 2, "half-true" : 3, "mostly-true" : 4, "TRUE" : 5}
print(y_label_dict)
# Out:
# {'pants-fire': 0, 'FALSE': 1, 'barely-true': 2, 'half-true': 3, 'mostly-true': 4, 'TRUE': 5}

# %%
data_L['output'] = data_L['Label'].apply(lambda x: y_label_dict[x])

# %%
data_L
# Out:
#             Index        Label  \
# 0       2635.json        FALSE
# 1      10540.json    half-true
# 2        324.json  mostly-true
# 3       1123.json        FALSE
# 4       9028.json    half-true
# 5      12465.json         TRUE
# 6       2342.json  barely-true
# 7        153.json    half-true
# 8       5602.json    half-true
# 9       9741.json  mostly-true
# 10      7115.json  mostly-true
# 11      4148.json    half-true
# 12      5947.json        FALSE
# 13      8616.json  mostly-true
# 14      8705.json  barely-true
# 15     10683.json    half-true
# 16       620.json         TRUE
# 17      3863.json  barely-true
# 18     12372.json    half-true
# 19     12385.json  mostly-true
# 20     10173.json        FALSE
# 21      9867.json  mostly-true
# 22     12408.json  mostly-true
# 23      2673.json    half-true
# 24      7057.json  barely-true
# 25     10215.json        FALSE
# 26     12517.json  mostly-true
# 27      3910.json    half-true
# 28     11092.json        FALSE
# ...

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer(oov_token='OOV')
data_L['token_statement']= tokenizer.fit_on_texts(data_L['Statement'])
data_L['token_statement']= tokenizer.texts_to_sequences(data_L['Statement'])
X_train = data_L['token_statement']
X_train = pad_sequences(X_train,padding= 'post', truncating='post')

# %%
X_train
# Out:
# array([[   8,    2, 6969, ...,    0,    0,    0],
#        [  64,  165,    2, ...,    0,    0,    0],
#        [ 128,  102, 3547, ...,    0,    0,    0],
#        ...,
#        [   8,   42, 3057, ...,    0,    0,    0],
#        [  12, 5041,    2, ...,    0,    0,    0],
#        [   2,  260,    4, ...,    0,    0,    0]])

# %%
data_L
# Out:
#             Index        Label  \
# 0       2635.json        FALSE
# 1      10540.json    half-true
# 2        324.json  mostly-true
# 3       1123.json        FALSE
# 4       9028.json    half-true
# 5      12465.json         TRUE
# 6       2342.json  barely-true
# 7        153.json    half-true
# 8       5602.json    half-true
# 9       9741.json  mostly-true
# 10      7115.json  mostly-true
# 11      4148.json    half-true
# 12      5947.json        FALSE
# 13      8616.json  mostly-true
# 14      8705.json  barely-true
# 15     10683.json    half-true
# 16       620.json         TRUE
# 17      3863.json  barely-true
# 18     12372.json    half-true
# 19     12385.json  mostly-true
# 20     10173.json        FALSE
# 21      9867.json  mostly-true
# 22     12408.json  mostly-true
# 23      2673.json    half-true
# 24      7057.json  barely-true
# 25     10215.json        FALSE
# 26     12517.json  mostly-true
# 27      3910.json    half-true
# 28     11092.json        FALSE
# ...

# %%
tokenizer.word_index

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
